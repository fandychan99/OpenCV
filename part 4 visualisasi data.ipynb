# %%
import pandas as pnd
import numpy as np
import matplotlib.pyplot as plt

# %%
#figure  & axes
fig = plt.figure()
ax = plt.axes()

# %%
X = np.linspace(0, 10, 100)
y = np.sqrt(X)

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(X, y)

# %%
y1 = np.sin(X)
y2 = np.cos(X)
