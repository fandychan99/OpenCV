# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Membuat data frame (df)

# %%
contoh_data = {'a' : [1,2,3], 'b':[4,5,6]}
contoh_data

# %%
pd.DataFrame(data=contoh_data)

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('Data/cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 72   21.0     3.0    60.0   FDA_25      3     1.0  0.75  39.106174
# 73   13.0    12.0    25.0   FDA_25      2     1.0  1.00  27.753301
# 74   17.0     3.0   115.0   FDA_25      1     1.0  0.67  49.787445
# 75   17.0     3.0   110.0   FDA_25      1     1.0  1.00  51.592193
# 76   16.0     8.0    60.0   FDA_25      1     1.0  0.75  36.187559

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     object
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 9.8+ KB

# %%
df.coloumns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19252\2425176728.py in ?()
# ----> 1 df.coloumns
#
# C:\ProgramData\anaconda3\envs\OpenCV\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coloumns'

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass      shelf     weight       cups     rating
# count  76.000000   75.000000  77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   2.207792   1.029610   0.821039  42.665705
# std     4.378656   70.410636   0.832524   0.150477   0.232716  14.047289
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (77, 16)

# %%
df.size
# Out:
# 1232

# %% [markdown]
# #### Get Coloumns & Rows

# %%
df.mfr #munculkan spesifik kolom
# Out:
# 0     N
# 1     Q
# 2     K
# 3     K
# 4     R
#      ..
# 72    G
# 73    G
# 74    R
# 75    G
# 76    G
# Name: mfr, Length: 77, dtype: object

# %%
df.mfr.head() #hanya 1 kolom saja
# Out:
# 0    N
# 1    Q
# 2    K
# 3    K
# 4    R
# Name: mfr, dtype: object

# %%
df['mfr'].head()
# Out:
# 0    N
# 1    Q
# 2    K
# 3    K
# 4    R
# Name: mfr, dtype: object

# %%
df['mfr','calories'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\envs\OpenCV\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\envs\OpenCV\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\envs\OpenCV\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('mfr', 'calories')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['mfr', 'calories']].head() #list di bungkus list lagi agar tidak error
# Out:
#   mfr  calories
# 0   N        70
# 1   Q       120
# 2   K        70
# 3   K        50
# 4   R       110

# %%
df.loc[2:6, 'calories':'sugars'] # karna location tidak ada batas atas batas bawah
# Out:
#    calories  protein  fat  sodium  fiber  carbo  sugars
# 2        70        4    1     260    9.0    7.0     5.0
# 3        50        4    0     140   14.0    8.0     0.0
# 4       110        2    2     200    1.0   14.0     8.0
# 5       110        2    2     180    1.5   10.5    10.0
# 6       110        2    0     125    1.0   11.0    14.0

# %% [markdown]
# ### mengganti kolom index

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %%
df = pd.read_csv('data/cereal.csv', index_col='name')
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Almond Delight              14.0     8.0     NaN   FDA_25      3     1.0
#
#                            cups     rating
# name
# ...

# %% [markdown]
# ### Dataframe summary

# %%
df.corr(numeric_only=True)
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.257638
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.025012
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.300003
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.297687
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.380357
# carbo     0.257638 -0.025012 -0.300003  0.297687 -0.380357  1.000000
# sugars    0.566533 -0.291853  0.302497  0.058866 -0.138760 -0.471184
# potass   -0.072063  0.563706  0.200445 -0.042632  0.911528 -0.365003
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.192650
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.138467
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.367460
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.088712
#
#             sugars    potass     shelf    weight      cups    rating
# ...

# %%
df.describe().T #Transpose
# Out:
#           count        mean        std        min         25%         50%  \
# calories   77.0  106.883117  19.484119  50.000000  100.000000  110.000000
# protein    77.0    2.545455   1.094790   1.000000    2.000000    3.000000
# fat        77.0    1.012987   1.006473   0.000000    0.000000    1.000000
# sodium     77.0  159.675325  83.832295   0.000000  130.000000  180.000000
# fiber      77.0    2.151948   2.383364   0.000000    1.000000    2.000000
# carbo      76.0   14.802632   3.907326   5.000000   12.000000   14.500000
# sugars     76.0    7.026316   4.378656   0.000000    3.000000    7.000000
# potass     75.0   98.666667  70.410636  15.000000   42.500000   90.000000
# shelf      77.0    2.207792   0.832524   1.000000    1.000000    2.000000
# weight     77.0    1.029610   0.150477   0.500000    1.000000    1.000000
# cups       77.0    0.821039   0.232716   0.250000    0.670000    0.750000
# rating     77.0   42.665705  14.047289  18.042851   33.174094   40.400208
#
# ...

# %% [markdown]
# ### Count

# %%
df.mfr.value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
df.rating
# Out:
# name
# 100% Bran                    68.402973
# 100% Natural Bran            33.983679
# All-Bran                     59.425505
# All-Bran with Extra Fiber    93.704912
# Almond Delight               34.384843
#                                ...
# Triples                      39.106174
# Trix                         27.753301
# Wheat Chex                   49.787445
# Wheaties                     51.592193
# Wheaties Honey Gold          36.187559
# Name: rating, Length: 77, dtype: float64

# %%
df[['rating']].head(20)
# Out:
#                               rating
# name
# 100% Bran                  68.402973
# 100% Natural Bran          33.983679
# All-Bran                   59.425505
# All-Bran with Extra Fiber  93.704912
# Almond Delight             34.384843
# Apple Cinnamon Cheerios    29.509541
# Apple Jacks                33.174094
# Basic 4                    37.038562
# Bran Chex                  49.120253
# Bran Flakes                53.313813
# Cap'n'Crunch               18.042851
# Cheerios                   50.764999
# Cinnamon Toast Crunch      19.823573
# Clusters                   40.400208
# Cocoa Puffs                22.736446
# Corn Chex                  41.445019
# Corn Flakes                45.863324
# Corn Pops                  35.782791
# Count Chocula              22.396513
# Cracklin' Oat Bran         40.448772

# %%
df[['rating']].mean()
# Out:
# rating    42.665705
# dtype: float64

# %%
df.rating.median()
# Out:
# 40.400208

# %% [markdown]
# ### Missing value/data Nan

# %%
df.isna().sum()
# Out:
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# ### Drop Data Na

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Almond Delight              14.0     8.0     NaN   FDA_25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
df.dropna().head() # menghapus data yang non available
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating
# name
# ...

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating
# name
# ...

# %% [markdown]
# ### Isi Data /Fillna

# %%
df.fillna('310').head() #jangan di gunakan sembarangan

# %%
isi_data = {'carbo':'10', 'sugars':'9', 'potass':'310'}
df.fillna(isi_data).head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating
# name
# ...

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating
# name
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
df.head(25)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# Apple Jacks                 K    C       110        2    0     125    1.0
# Basic 4                     G    C       130        3    2     210    2.0
# Bran Chex                   R    C        90        2    1     200    4.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cap'n'Crunch                Q    C       120        1    2     220    0.0
# Cheerios                    G    C       110        6    2     290    2.0
# Cinnamon Toast Crunch       G    C       120        1    3     210    0.0
# ...

# %%
df.to_csv('Data/cerealedit1.csv', index_label='name')

# %% [markdown]
# ### menggunakan data yang tersimpan

# %%
df1 = pd.read_csv('Data/cerealedit1.csv', index_col = 'name')
df1.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating
# name
# ...

# %%
df1[df1.rating > 70]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Shredded Wheat 'n'Bran      19.0     0.0   140.0    FDA_0      1     1.0
# Shredded Wheat spoon size   20.0     0.0   120.0    FDA_0      1     1.0
#
#                            cups     rating
# name
# All-Bran with Extra Fiber  0.50  93.704912
# Shredded Wheat 'n'Bran     0.67  74.472949
# Shredded Wheat spoon size  0.67  72.801787

# %%
df1[(df1.rating > 50) & (df1.fat == 0)]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Frosted Mini-Wheats         K    C       100        3    0       0    3.0
# Grape-Nuts                  P    C       110        3    0     170    3.0
# Nutri-grain Wheat           K    C        90        3    0     170    3.0
# Puffed Rice                 Q    C        50        1    0       0    0.0
# Puffed Wheat                Q    C        50        2    0       0    1.0
# Raisin Squares              K    C        90        2    0       0    2.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# Special K                   K    C       110        6    0     230    1.0
# ...

# %%
df1[(df1.rating > 50) | (df1.fat == 0)]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Jacks                 K    C       110        2    0     125    1.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cheerios                    G    C       110        6    2     290    2.0
# Corn Chex                   R    C       110        2    0     280    0.0
# Corn Flakes                 K    C       100        2    0     290    1.0
# Corn Pops                   K    C       110        1    0      90    1.0
# Crispix                     K    C       110        2    0     220    1.0
# Double Chex                 R    C       100        2    0     190    1.0
# Frosted Flakes              K    C       110        1    0     200    1.0
# ...

# %% [markdown]
# ### membuat kolom baru

# %%
df1['kolom_new'] = np.random.rand(len(df1))
df1.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating  kolom_new
# name
# ...

# %%
df1.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating  kolom_new
# name
# ...

# %%
df1['kolom_baru2'] = np.random.rand(len(df1))

# %%
df1.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating  kolom_new  kolom_baru2
# ...

# %%
df1.drop(columns='kolom_new', inplace=True)
df1.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0    FDA_0      3     1.0
# All-Bran                     7.0     5.0   320.0   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Apple Cinnamon Cheerios     10.5    10.0    70.0   FDA_25      1     1.0
#
#                            cups     rating  kolom_baru2
# name
# ...
